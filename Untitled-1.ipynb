# %%
import torch
ckpt = torch.load('entropy_model_checkpoints/best_model_checkpoint.pt', map_location='cpu')
state = ckpt['model_state_dict']
print("num params tensors:", len(state))
for i, (k, v) in enumerate(state.items()):
    print(k, tuple(v.shape))
    if i >= 20:
        break
# Out:
# num params tensors: 22
# transformer.wte.weight (256, 32)
# transformer.wpe.weight (128, 32)
# transformer.h.0.ln_1.weight (32,)
# transformer.h.0.attn.c_attn.weight (96, 32)
# transformer.h.0.attn.c_proj.weight (32, 32)
# transformer.h.0.ln_2.weight (32,)
# transformer.h.0.mlp.c_fc.weight (128, 32)
# transformer.h.0.mlp.c_proj.weight (32, 128)
# transformer.h.1.ln_1.weight (32,)
# transformer.h.1.attn.c_attn.weight (96, 32)
# transformer.h.1.attn.c_proj.weight (32, 32)
# transformer.h.1.ln_2.weight (32,)
# transformer.h.1.mlp.c_fc.weight (128, 32)
# transformer.h.1.mlp.c_proj.weight (32, 128)
# transformer.h.2.ln_1.weight (32,)
# transformer.h.2.attn.c_attn.weight (96, 32)
# transformer.h.2.attn.c_proj.weight (32, 32)
# transformer.h.2.ln_2.weight (32,)
# transformer.h.2.mlp.c_fc.weight (128, 32)
# transformer.h.2.mlp.c_proj.weight (32, 128)
# transformer.ln_f.weight (32,)
# ...

# %%
ckpt = torch.load('entropy_model_checkpoints/ETTh1.pt', map_location='cpu')
state = ckpt['model_state_dict']
print("num params tensors:", len(state))
for i, (k, v) in enumerate(state.items()):
    print(k, tuple(v.shape))
    if i >= 20:
        break
# Out:
# num params tensors: 16
# transformer.wte.weight (256, 32)
# transformer.wpe.weight (96, 32)
# transformer.h.0.ln_1.weight (32,)
# transformer.h.0.attn.c_attn.weight (96, 32)
# transformer.h.0.attn.c_proj.weight (32, 32)
# transformer.h.0.ln_2.weight (32,)
# transformer.h.0.mlp.c_fc.weight (128, 32)
# transformer.h.0.mlp.c_proj.weight (32, 128)
# transformer.h.1.ln_1.weight (32,)
# transformer.h.1.attn.c_attn.weight (96, 32)
# transformer.h.1.attn.c_proj.weight (32, 32)
# transformer.h.1.ln_2.weight (32,)
# transformer.h.1.mlp.c_fc.weight (128, 32)
# transformer.h.1.mlp.c_proj.weight (32, 128)
# transformer.ln_f.weight (32,)
# lm_head.weight (256, 32)
# ...
